# %% [markdown]
# # Text to Multiclass Explanation: Language Modelling Example

# %% [markdown]
# This notebook demostrates how to get explanations for the top-k next words generated by a language model. In this demo, we use the pretrained gpt2 model provided by hugging face (https://huggingface.co/gpt2) to predict the top-k next words. By looking at the top-k next words, we treat them as k separate classes and then learn the explanations for each of this k words. We thereby are able to explain the contribution of words in the input that are responsible for the liklihood of the top-k next words to be predicted.

# %%
import numpy as np
from transformers import AutoTokenizer, AutoModelWithLMHead
import shap
import torch

# %% [markdown]
# ### Load model and tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained('t5-base', use_fast=True)
model = AutoModelWithLMHead.from_pretrained('t5-base').cuda()
# Out:
# The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %% [markdown]
# We next wrap the model with the TopKLM model which extracts the log odds of the top-k next words and also create a Text masker by initializing it with the mask_token = "..." and set collapse_mask_token = True, which is used for infilling text during perturbation of the inputs.

# %%
wrapped_model = shap.models.TopKLM(model, tokenizer, k=100)
masker = shap.maskers.Text(tokenizer, mask_token = '<mask>', collapse_mask_token=True)

# %% [markdown]
# ### Define data

# %% [markdown]
# Here we set the initial text for which we want the gpt2 model to predict the next word

# %%
s = ["In a shocking finding, scientists discovered a herd of unicorns living in a"]

# %% [markdown]
# ### Create explainer object

# %%
explainer = shap.Explainer(wrapped_model,masker)

# %% [markdown]
# ### Compute SHAP values

# %%
shap_values = explainer(s)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-8-9534076d561d> in <module>
# ----> 1 shap_values = explainer(s)
#
# /ext3/miniconda3/lib/python3.8/site-packages/shap/explainers/_explainer.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     253             feature_names = [[] for _ in range(len(args))]
#     254         for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 255             row_result = self.explain_row(
#     256                 *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     257                 batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#
# /ext3/miniconda3/lib/python3.8/site-packages/shap/explainers/_partition.py in explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, fixed_context, *row_args)
#     127         # if not fixed background or no base value assigned then compute base value for a row
#     128         if self._curr_base_value is None or not getattr(self.masker, "fixed_background", False):
# --> 129             self._curr_base_value = fm(m00.reshape(1, -1))[0]
#     130         f11 = fm(~m00.reshape(1, -1))[0]
#     131
#
# /ext3/miniconda3/lib/python3.8/site-packages/shap/utils/_masked_model.py in __call__(self, masks, batch_size)
#      59
#      60         else:
# ---> 61             return self._full_masking_call(masks, batch_size=batch_size)
#      62
#      63     def _full_masking_call(self, masks, batch_size=None):
#
# /ext3/miniconda3/lib/python3.8/site-packages/shap/utils/_masked_model.py in _full_masking_call(self, masks, batch_size)
#     132
#     133         joined_masked_inputs = self._stack_inputs(*all_masked_inputs)
# --> 134         outputs = self.model(*joined_masked_inputs)
#     135         _assert_output_input_match(joined_masked_inputs, outputs)
#     136
#
# /ext3/miniconda3/lib/python3.8/site-packages/shap/models/_topk_lm.py in __call__(self, masked_X, X)
#      86         """
#      87         output_batch = None
# ---> 88         self.update_cache_X(X[:1])
#      89         start_batch_idx, end_batch_idx = 0, len(masked_X)
#      90         while start_batch_idx < end_batch_idx:
#
# /ext3/miniconda3/lib/python3.8/site-packages/shap/models/_topk_lm.py in update_cache_X(self, X)
#     112         if (self.X is None) or (not np.array_equal(self.X, X)):
#     113             self.X = X
# --> 114             self.output_names = self.get_output_names_and_update_topk_token_ids(self.X)
#     115
#     116     def get_output_names_and_update_topk_token_ids(self, X):
#
# /ext3/miniconda3/lib/python3.8/site-packages/shap/models/_topk_lm.py in get_output_names_and_update_topk_token_ids(self, X)
#     133
#     134         # otherwise we pick the top k tokens from the model
# --> 135         self.topk_token_ids = self.generate_topk_token_ids(X)
#     136         output_names = [self.tokenizer.decode([x]) for x in self.topk_token_ids]
#     137         return output_names
#
# /ext3/miniconda3/lib/python3.8/site-packages/shap/models/_topk_lm.py in generate_topk_token_ids(self, X)
#     195             An array of top-k token ids.
#     196         """
# --> 197         logits = self.get_lm_logits(X)
#     198         topk_tokens_ids = (-logits).argsort()[0, :self.k]
#     199         return topk_tokens_ids
#
# /ext3/miniconda3/lib/python3.8/site-packages/shap/models/_topk_lm.py in get_lm_logits(self, X)
#     235                         print(e)
#     236                 logits = outputs.logits.numpy().astype('float64')[:, -1, :]
# --> 237         return logits
#     238
#     239     def save(self, out_file):
#
# UnboundLocalError: local variable 'logits' referenced before assignment

# %% [markdown]
# ### Visualize the SHAP values across the input sentence for the top-k next words

# %% [markdown]
# We can now see the top-k next words predicted by gpt2 under "Output Text" in the viz plot below and hover over each of the token to understand which words in the input sentence are driving the generation of the particular output word to be predicted

# %%
shap.plots.text(shap_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-64c2b2deb066> in <module>
# ----> 1 shap.plots.text(shap_values)
#
# NameError: name 'shap_values' is not defined
